# %% [markdown]
# # Desafio 1:

# %%
cidade = " rio de janeiro "
cidade = (cidade.strip())
cidade = (cidade.upper())
print(cidade)
# Out:
# RIO DE JANEIRO

# %% [markdown]
# # Desafio 2:

# %%
velocidade = int(input())
if velocidade > 80:
  print("Multado")
else:
  print("Dentro do limite")
# Out:
# 81
# Multado

# %% [markdown]
# # Desafio 3

# %%
idade = [15, 22, 18, 12, 30]
maiores = 0
for idade in idade:
  if idade >= 18:
    maiores = maiores + 1

print(f"O Total é {maiores}")
# Out:
# O Total é 3

# %% [markdown]
# # Desafio 4

# %%
def saudacao(nome):
  print(f"Olá, {nome}! Bem vinda à equipe de dados!")
nome = input()
saudacao(nome)
# Out:
# Milena
# Olá, Milena! Bem vinda à equipe de dados!
